# %% [markdown]
# ##  Explore Open Datasets

# %% [markdown]
# ## You can download a data set of your own choice in csv format, from the following repositories.
# ### kaggle
# ### google dataset search
# ### UCI machine learning repository

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS
# ## EDA is the process of analyzing datasets to summarize their main characteristics, often using visuals and statistics-
# ## before applying any machine learning or predictive models
# ## EDA helps you understand your data — what it looks like, what it contains, what’s missing, and what patterns might be present.

# %% [markdown]
# # Goals of EDA
# ### 1.Understand the structure of the data
#
# ### 2.Identify patterns, trends, and relationships
#
# ### 3.Spot missing values or outliers
#
# ### 4.Detect errors or anomalies
#
# ### 5.Decide on next steps for modeling or cleaning

# %% [markdown]
# # Typical EDA Tasks
# ### A. Basic Info
# #### Shape of the dataset (rows and columns)
#
# #### Data types of each column
#
# #### Checking for null or missing values

# %% [markdown]
# # 1. How big is the data?

# %%
import pandas as pd

df = pd.read_csv("/kaggle/input/datasets/muhammadjasimai/trian-lab5/train.csv")

print(df.shape)
# Out:
# (891, 12)

# %%
len(df)
# Out:
# 891

# %%
len(df.columns)
# Out:
# 12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 2. How does the data look like?

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.head
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]>

# %% [markdown]
# # 3. What is the datatype of each column?

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 5. Data Summary

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())


df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.head(14)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male  28.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S

# %%
df['Embarked'].fillna('Karachi', inplace=True)
# Out:
# /tmp/ipykernel_55/330978562.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna('Karachi', inplace=True)

# %%
df['Embarked'] = df['Embarked'].fillna('Karachi')

# %%
df.drop('Cabin',axis =1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_55/188821558.py in <cell line: 0>()
# ----> 1 df.drop('Cabin',axis =1,inplace = True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5601                 weight  1.0     0.8
#    5602         """
# -> 5603         return super().drop(
#    5604             labels=labels,
#    5605             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808         for axis, labels in axes.items():
#    4809             if labels is not None:
# -> 4810                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4811
#    4812         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4850                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4851             else:
# -> 4852                 new_axis = axis.drop(labels, errors=errors)
#    4853             indexer = axis.get_indexer(new_axis)
#    4854
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7134         if mask.any():
#    7135             if errors != "ignore":
# -> 7136                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137             indexer = indexer[~mask]
#    7138         return self.delete(indexer)
#
# KeyError: "['Cabin'] not found in axis"

# %%
df.drop('Passenengerid',axis =1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_55/2061642473.py in <cell line: 0>()
# ----> 1 df.drop('Passenengerid',axis =1,inplace = True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5601                 weight  1.0     0.8
#    5602         """
# -> 5603         return super().drop(
#    5604             labels=labels,
#    5605             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808         for axis, labels in axes.items():
#    4809             if labels is not None:
# -> 4810                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4811
#    4812         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4850                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4851             else:
# -> 4852                 new_axis = axis.drop(labels, errors=errors)
#    4853             indexer = axis.get_indexer(new_axis)
#    4854
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7134         if mask.any():
#    7135             if errors != "ignore":
# -> 7136                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137             indexer = indexer[~mask]
#    7138         return self.delete(indexer)
#
# KeyError: "['Passenengerid'] not found in axis"

# %% [markdown]
# # 6. Handling missing values/ Data Cleaning
# ### 1. Detecting missing values
# ### isnull.sum
# ### 2. Replace missing values
# ### fillna
# ### syntax = (value, method=None, axis=None, inplace=False, limit=None)
# ### 3. Remove missing values
# ### dropna function (The dropna() method is used to remove rows or columns that contain missing values       (NaN or None).)
# ### syntax (axis=0, how='any', thresh=None, subset=None, inplace=False)
# ### 4. drop
# ### 5. drop_duplicates

# %% [markdown]
# ### 1. Are there any missing values?

# %% [markdown]
# ### 2. Check duplicate values

# %% [markdown]
# # handling categorical data
# # B. Univariate Analysis
# ### Distribution of each variable separately
#
# ### Frequency of categories or summary stats (mean, median, etc.)
#
# ## For Categorical Data: (e.g., gender, country, color)
#
# #### Tasks: Count plots, bar charts, value counts, pie charts.
#
# #### Purpose: To see how many times each category appears.
#
# #### Example: How many males vs. females are in the data?

# %%
ds['Survived'].value_counts().plot(kind='bar')
#how many passengers survived (1) vs did not survive (0).
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## For Numerical Data: (e.g., age, salary, height)
#
# #### Tasks: Histograms, boxplots,  summary stats (mean, median, etc.)
#
# #### Purpose: Understand the distribution — is it skewed? Are there outliers?
#
# #### Example: What is the average age? Is the salary distribution normal?

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Bivariate/Multivariate Analysis

# %% [markdown]
# # This means analyzing the relationship between two variables.(or more variables)
#
# # Numerical vs Numerical:
#
# #### Tools: Scatter plots, correlation heatmaps, pair plots.
#
# #### Example: Is there a correlation between age and salary?
#
# # Categorical vs Numerical:
#
# ###  Tools: Boxplots, violin plots, grouped bar charts.
#
# #### Example: What is the average salary by gender?
#
# # Categorical vs Categorical:
#
# #### Tools: Crosstabs, stacked bar charts, grouped count plots.
#
# #### Example: Count of people from each country split by gender.

# %%
import seaborn as sns

titanic = df
sns.barplot(x=titanic['Pclass'],y=titanic['Age'],hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ##### hue adds a third variable by using different colors to represent different categories. In this case:
#
# ##### For each class (Pclass), the bar is split into Male and Female parts.
#
# ##### The bar shows the average age of each gender within each class.

# %% [markdown]
# # see pairplot, heatmap, boxplot

# %% [markdown]
# # convert float to int for age

# %% [markdown]
# # using univariate analysis specifically pie chart,
# # show which gender was more in number on titanic,
# # show the percentage of persons that were dead,
#  # show a histogram of age versus gender, show a histogram of survival/dead over gender. #filter out the number of teenagers and the number of older people.
# # using a pie chart show the survival distribution of tennage over dead/alive, as well as older over dead/alive

# %% [markdown]
# # Feature Engineering is the process of creating new input features or modifying existing ones to make them more useful for a machine learning model.
# # in the titanic dataset Create a new feature by extracting titles like "Mr", "Mrs", etc. from the Name column.
# # create a new feature family size by adding the sibsp and parch column values
